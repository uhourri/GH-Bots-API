# %%
import requests
import json

# %%
# GitHub personal token
API_TOKEN = "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"

# Set up request headers
HEADERS = {
    "Accept": "application/vnd.github.v3+json",
    "Authorization": f"Bearer {API_TOKEN}"
}

# %%
def get_repo_events(owner, repo):
    # GitHub API endpoint to get repository events
    url = f"https://api.github.com/repos/{owner}/{repo}/events"

    try:
        response = requests.get(url, headers=HEADERS)

        if response.status_code == 200:
            # Successfully retrieved the events
            events = response.json()

            output = "../data/{}-{}-events.json".format(owner,repo)

            # Save the events
            with open(output, "w") as f:
                json.dump(events, f, indent=4)

            print(f"Events saved for : {owner}/{repo}")
        else:
            print(f"Failed to retrieve events from : {owner}/{repo}")
    except Exception as e:
        print(f"An error occurred: {str(e)}, {owner/repo}")

# %%
def get_repo_names(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)

    # Extract repository names
    repo_names = [(item["name"].split('/')[0], item["name"].split('/')[1]) for item in data["items"]]

    return repo_names

# %%
relevent_repos = get_repo_names('../data/00relevent-repos.json')

# %%
for owner, repo in relevent_repos:
    get_repo_events(owner, repo)
# Out:
# Events saved for : sparklemotion/nokogiri
# Events saved for : jdbi/jdbi
# Events saved for : elastic/elasticsearch
# Events saved for : robolectric/robolectric
# Events saved for : rabbitmq/rabbitmq-java-client
# Events saved for : dcm4che/dcm4che
# Events saved for : spring-projects/spring-data-jpa
# Events saved for : spring-projects/spring-data-commons
# Events saved for : spockframework/spock
# Events saved for : dropwizard/dropwizard
# Events saved for : movingblocks/terasology
# Events saved for : apache/bookkeeper
# Events saved for : cucumber/cucumber-jvm
# Events saved for : spring-projects/spring-data-redis
# Events saved for : liquibase/liquibase
# Events saved for : cgeo/cgeo
# Events saved for : eclipse/jetty.project
# Events saved for : opentripplanner/opentripplanner
# Events saved for : spring-projects/spring-integration
# Events saved for : usc-isi-i2/web-karma
# Events saved for : spring-projects/spring-data-neo4j
# Events saved for : spring-projects/spring-data-mongodb
# Events saved for : javaparser/javaparser
# Events saved for : axonframework/axonframework
# Events saved for : azure/azure-sdk-for-java
# Events saved for : mcmmo-dev/mcmmo
# Events saved for : spring-projects/spring-security
# Events saved for : selenide/selenide
# Events saved for : pgjdbc/pgjdbc
# Events saved for : getsentry/sentry-java
# Events saved for : cloudfoundry/uaa
# Events saved for : graphhopper/graphhopper
# Events saved for : spring-projects/spring-data-rest
# Events saved for : dotcms/core
# Events saved for : hazelcast/hazelcast
# Events saved for : magefree/mage
# Events saved for : sonarsource/sonarjs
# Events saved for : universalmediaserver/universalmediaserver
# Events saved for : geonetwork/core-geonetwork
# Events saved for : mekanism/mekanism
# Events saved for : owncloud/android
# Events saved for : xerial/snappy-java
# Events saved for : activiti/activiti
# Events saved for : vaadin/framework
# Events saved for : apache/druid
# Events saved for : adjust/android_sdk
# Events saved for : ovirt/ovirt-engine
# Events saved for : orientechnologies/orientdb
# Events saved for : alluxio/alluxio
# Events saved for : seleniumhq/selenium
# Events saved for : google/dagger
# Events saved for : orcid/orcid-source
# Events saved for : elastic/elasticsearch-hadoop
# Events saved for : netflix/zuul
# Events saved for : wordpress-mobile/wordpress-android
# Events saved for : crate/crate
# Events saved for : code4craft/webmagic
# Events saved for : apache/cloudstack
# Events saved for : square/picasso
# Events saved for : spring-projects/spring-data-couchbase
# Events saved for : openhft/chronicle-queue
# Events saved for : bumptech/glide
# Events saved for : dependencytrack/dependency-track
# Events saved for : ontop/ontop
# Events saved for : datadog/jmxfetch
# Events saved for : exist-db/exist
# Events saved for : codelibs/fess
# Events saved for : konsoletyper/teavm
# Events saved for : linkedin/ambry
# Events saved for : iqss/dataverse
# Events saved for : inria/spoon
# Events saved for : awslabs/amazon-kinesis-client
# Events saved for : wso2/carbon-kernel
# Events saved for : google/j2objc
# Events saved for : cryptomator/cryptomator
# Events saved for : mucommander/mucommander
# Events saved for : osmdroid/osmdroid
# Events saved for : myrobotlab/myrobotlab
# Events saved for : wso2/product-is
# Events saved for : questdb/questdb
# Events saved for : lettuce-io/lettuce-core
# Events saved for : google/guava
# Events saved for : wso2/product-apim
# Events saved for : bazelbuild/bazel
# Events saved for : spring-cloud/spring-cloud-config
# Events saved for : opengamma/strata
# Events saved for : spring-projects/spring-session
# Events saved for : braintree/braintree_android
# Events saved for : teamamaze/amazefilemanager
# Events saved for : google/error-prone
# Events saved for : nlpchina/elasticsearch-sql
# Events saved for : spongepowered/spongeapi
# Events saved for : payara/payara
# Events saved for : appliedenergistics/applied-energistics-2
# Events saved for : junit-team/junit5
# Events saved for : datadog/java-dogstatsd-client
# Events saved for : zendesk/maxwell
# Events saved for : eclipse/che
# Events saved for : testcontainers/testcontainers-java
# Events saved for : google/google-java-format
# Events saved for : resilience4j/resilience4j
# Events saved for : sepinf-inc/iped
# Events saved for : bardsoftware/ganttproject
# Events saved for : graphql-java/graphql-java
# Events saved for : fabric8io/kubernetes-client
# Events saved for : spring-cloud/spring-cloud-dataflow
# Events saved for : getodk/collect
# Events saved for : scalecube/scalecube-services
# Events saved for : android/android-test
# Events saved for : commons-app/apps-android-commons
# Events saved for : palantir/gradle-git-version
# Events saved for : palantir/conjure-java-runtime
# Events saved for : yahoo/elide
# Events saved for : dbeaver/dbeaver
# Events saved for : netflix/photon
# Events saved for : lawnchairlauncher/lawnchair
# Events saved for : branchmetrics/cordova-ionic-phonegap-branch-deep-linking-attribution
# Events saved for : pcgen/pcgen
# Events saved for : obsidiandynamics/kafdrop
# Events saved for : corretto/corretto-8
# Events saved for : airbnb/lottie-android
# Events saved for : azuread/microsoft-authentication-library-for-android
# Events saved for : netflix/hollow
# Events saved for : wso2/micro-integrator
# Events saved for : supertokens/supertokens-core
# Events saved for : oracle/weblogic-kubernetes-operator
# Events saved for : stleary/json-java
# Events saved for : jmonkeyengine/jmonkeyengine
# Events saved for : roaringbitmap/roaringbitmap
# Events saved for : bazelbuild/bazel-buildfarm
# Events saved for : braintree/braintree-android-drop-in
# Events saved for : apache/rocketmq
# Events saved for : alibaba/datax
# Events saved for : google/data-transfer-project
# Events saved for : federicoiosue/omni-notes
# Events saved for : tng/archunit
# Events saved for : googleapis/google-cloud-java
# Events saved for : codenameone/codenameone
# Events saved for : appiumtestdistribution/appiumtestdistribution
# Events saved for : nightscoutfoundation/xdrip
# Events saved for : skriptlang/skript
# Events saved for : oracle/oci-java-sdk
# Events saved for : googleapis/java-pubsub
# Events saved for : googlecontainertools/jib
# Events saved for : software-mansion/react-native-gesture-handler
# Events saved for : reactor/reactor-core
# Events saved for : sofastack/sofa-rpc
# Events saved for : web3j/web3j
# Events saved for : nextcloud/android
# Events saved for : apache/servicecomb-java-chassis
# Events saved for : neo4j-contrib/neo4j-apoc-procedures
# Events saved for : rsksmart/rskj
# Events saved for : spring-projects/sts4
# Events saved for : axelor/axelor-open-suite
# Events saved for : azuread/microsoft-authentication-library-for-java
# Events saved for : seata/seata
# Events saved for : pinpoint-apm/pinpoint
# Events saved for : isoron/uhabits
# Events saved for : tronprotocol/java-tron
# Events saved for : spotbugs/spotbugs
# Events saved for : apache/netbeans
# Events saved for : actiontech/dble
# Events saved for : palantir/conjure
# Events saved for : open-telemetry/opentelemetry-java-instrumentation
# Events saved for : microsoft/applicationinsights-java
# Events saved for : microsoft/azure-tools-for-java
# Events saved for : wso2/carbon-identity-framework
# Events saved for : alibaba/nacos
# Events saved for : thingsboard/thingsboard
# Events saved for : openapitools/openapi-generator
# Events saved for : apache/pulsar
# Events saved for : janusgraph/janusgraph
# Events saved for : flowable/flowable-engine
# Events saved for : metersphere/metersphere
# Events saved for : spring-cloud/spring-cloud-gateway
# Events saved for : micrometer-metrics/micrometer
# Events saved for : strimzi/strimzi-kafka-operator
# Events saved for : ant-media/ant-media-server
# Events saved for : apache/hudi
# Events saved for : kubernetes-client/java
# Events saved for : pravega/pravega
# Events saved for : feast-dev/feast
# Events saved for : apache/iotdb
# Events saved for : spring-cloud/spring-cloud-commons
# Events saved for : apache/plc4x
# Events saved for : confluentinc/parallel-consumer
# Events saved for : grpc/grpc-java
# Events saved for : kickstarter/android-oss
# Events saved for : micronaut-projects/micronaut-core
# Events saved for : confluentinc/ksql
# Events saved for : netflix/conductor
# Events saved for : apache/iceberg
# Events saved for : googlecloudplatform/dataflowtemplates
# Events saved for : batfish/batfish
# Events saved for : airbytehq/airbyte
# Events saved for : azure/azure-sdk-for-android
# Events saved for : cashapp/sqldelight
# Events saved for : corda/corda
# Events saved for : kotlin/kotlinx.serialization
# Events saved for : mikepenz/aboutlibraries
# Events saved for : kotlin/dokka
# Events saved for : mapbox/mapbox-navigation-android
# Events saved for : datadog/dd-trace-java
# Events saved for : oracle/graal
# Events saved for : quarkusio/quarkus
# Events saved for : apache/beam
# Events saved for : vespa-engine/vespa
# Events saved for : open-telemetry/opentelemetry-java
# Events saved for : kotlin/kotlinx.coroutines
# Events saved for : ktorio/ktor
# Events saved for : detekt/detekt
# Events saved for : duckduckgo/android
# Events saved for : vector-im/element-android
# Events saved for : stripe/stripe-android
# Events saved for : kotlin/kotlinx-datetime
# Events saved for : pytorch/serve
# Events saved for : mamoe/mirai
# Events saved for : kotest/kotest
# Events saved for : google/ksp
# Events saved for : woocommerce/woocommerce-android
# Events saved for : hapifhir/hapi-fhir
# Events saved for : pojavlauncherteam/pojavlauncher
# Events saved for : ionic-team/capacitor
# Events saved for : netflix/dgs-framework
# Events saved for : mono/skiasharp
# Events saved for : microsoft/ptvs
# Events saved for : adamhathcock/sharpcompress
# Events saved for : powershell/psscriptanalyzer
# Events saved for : dotnet/maui
# Events saved for : recurly/recurly-client-dotnet
# Events saved for : confluentinc/confluent-kafka-dotnet
# Events saved for : riganti/dotvvm
# Events saved for : azure/azure-functions-templates
# Events saved for : stackexchange/stackexchange.redis
# Events saved for : stripe/stripe-dotnet
# Events saved for : googleads/googleads-mobile-unity
# Events saved for : virtocommerce/vc-platform
# Events saved for : nettopologysuite/nettopologysuite
# Events saved for : azure-samples/cognitive-services-speech-sdk
# Events saved for : azure/azure-functions-durable-extension
# Events saved for : couchbase/couchbase-lite-net
# Events saved for : microsoft/sqltoolsservice
# Events saved for : grpc/grpc-dotnet
# Events saved for : unigramdev/unigram
# Events saved for : microsoft/azure-pipelines-agent
# Events saved for : unity-technologies/inputsystem
# Events saved for : odata/webapi
# Events saved for : azure/durabletask
# Events saved for : odata/odata.net
# Events saved for : aspnetboilerplate/aspnetboilerplate
# Events saved for : dotnet/machinelearning
# Events saved for : microsoft/faster
# Events saved for : akkadotnet/akka.net
# Events saved for : elastic/elasticsearch-net
# Events saved for : dotnet/docfx
# Events saved for : cosmosos/cosmos
# Events saved for : xamarin/xamarin-macios
# Events saved for : xamarin/xamarin-android
# Events saved for : azure/azure-functions-host
# Events saved for : dotnet/wcf
# Events saved for : jasperfx/marten
# Events saved for : actions/runner
# Events saved for : opcfoundation/ua-.netstandard
# Events saved for : azuread/azure-activedirectory-identitymodel-extensions-for-dotnet
# Events saved for : azuread/microsoft-authentication-library-for-dotnet
# Events saved for : azure/azure-functions-core-tools
# Events saved for : dotnet/installer
# Events saved for : microsoft/vstest
# Events saved for : firelyteam/firely-net-sdk
# Events saved for : chummer5a/chummer5a
# Events saved for : microsoft/powerapps-samples
# Events saved for : powershell/powershelleditorservices
# Events saved for : dotnet/scaffolding
# Events saved for : microsoft/testfx
# Events saved for : azure/azure-cosmos-dotnet-v3
# Events saved for : azuread/microsoft-identity-web
# Events saved for : azure/industrial-iot
# Events saved for : azure/azure-sdk-tools
# Events saved for : libgit2/rugged
# Events saved for : lldpd/lldpd
# Events saved for : nvidia/gdrcopy
# Events saved for : haiwen/seafile
# Events saved for : aircrack-ng/aircrack-ng
# Events saved for : mapserver/mapserver
# Events saved for : hanskristian-work/vkd3d-proton
# Events saved for : riscv/riscv-openocd
# Events saved for : janet-lang/janet
# Events saved for : liballeg/allegro5
# Events saved for : rhomobile/rhodes
# Events saved for : expensify/bedrock
# Events saved for : openhpc/ohpc
# Events saved for : paparazzi/paparazzi
# Events saved for : asterisk/asterisk
# Events saved for : rrze-hpc/likwid
# Events saved for : pjsip/pjproject
# Events saved for : adobe-type-tools/afdko
# Events saved for : pocl/pocl
# Events saved for : thesofproject/sof
# Events saved for : audacity/audacity
# Events saved for : openenclave/openenclave
# Events saved for : iovisor/bcc
# Events saved for : libgit2/libgit2
# Events saved for : openzfs/zfs
# Events saved for : pocoproject/poco
# Events saved for : ponylang/ponyc
# Events saved for : johnkerl/miller
# Events saved for : weechat/weechat
# Events saved for : geany/geany
# Events saved for : spdk/spdk
# Events saved for : dynamorio/dynamorio
# Events saved for : inavflight/inav
# Events saved for : syslog-ng/syslog-ng
# Events saved for : bitcraze/crazyflie-firmware
# Events saved for : groonga/groonga
# Events saved for : ngtcp2/ngtcp2
# Events saved for : networkupstools/nut
# Events saved for : awslabs/amazon-kinesis-video-streams-webrtc-sdk-c
# Events saved for : freifunk-gluon/gluon
# Events saved for : cbsd/cbsd
# Events saved for : tempesta-tech/tempesta
# Events saved for : unknownshadow200/classicube
# Events saved for : ofiwg/libfabric
# Events saved for : microsoft/powershell-dsc-for-linux
# Events saved for : dynamods/dynamo
# Events saved for : microsoft/botbuilder-dotnet
# Events saved for : graphql-dotnet/graphql-dotnet
# Events saved for : dotnetcore/wtm
# Events saved for : discord-net/discord.net
# Events saved for : elsa-workflows/elsa-core
# Events saved for : azure/iotedge
# Events saved for : realm/realm-dotnet
# Events saved for : microsoft/openapi.net
# Events saved for : epplussoftware/epplus
# Events saved for : elastic/apm-agent-dotnet
# Events saved for : avaloniaui/avalonia
# Events saved for : dotnet/efcore
# Events saved for : bitwarden/server
# Events saved for : gitextensions/gitextensions
# Events saved for : radarr/radarr
# Events saved for : sixlabors/imagesharp
# Events saved for : dotnet/msbuild
# Events saved for : unoplatform/uno
# Events saved for : eventstore/eventstore
# Events saved for : dotnet-boxed/templates
# Events saved for : npgsql/npgsql
# Events saved for : bitwarden/mobile
# Events saved for : azure/azure-sdk-for-net
# Events saved for : linq2db/linq2db
# Events saved for : lidarr/lidarr
# Events saved for : scisharp/tensorflow.net
# Events saved for : tmodloader/tmodloader
# Events saved for : dotnet/samples
# Events saved for : dafny-lang/dafny
# Events saved for : revolutionary-games/thrive
# Events saved for : sonarsource/sonar-dotnet
# Events saved for : dotnet/aspnetcore
# Events saved for : dotnet-architecture/eshoponcontainers
# Events saved for : dotnet/roslyn
# Events saved for : kiminewt/pyshark
# Events saved for : bioconda/bioconda-utils
# Events saved for : enarjord/passivbot
# Events saved for : iina/iina
# Events saved for : apple/swift-nio
# Events saved for : apple/swift-syntax
# Events saved for : stripe/stripe-ios
# Events saved for : vapor/vapor
# Events saved for : realm/swiftlint
# Events saved for : apple/swift-package-manager
# Events saved for : signalapp/signal-ios
# Events saved for : wordpress-mobile/wordpress-ios
# Events saved for : pointfreeco/swift-composable-architecture
# Events saved for : mozilla-mobile/focus-ios
# Events saved for : quicksilver/quicksilver
# Events saved for : googleads/googleads-mobile-ios-examples
# Events saved for : branchmetrics/ios-branch-deep-linking-attribution
# Events saved for : matrix-org/matrix-ios-sdk
# Events saved for : braintree/braintree-ios-drop-in
# Events saved for : powerjob/powerjob
# Events saved for : roaringbitmap/croaring
# Events saved for : azure/azure-uamqp-c
# Events saved for : analogdevicesinc/libiio
# Events saved for : igraph/igraph
# Events saved for : transmission/transmission
# Events saved for : ucb-bar/chipyard
# Events saved for : intel/libva
# Events saved for : mgba-emu/mgba
# Events saved for : redisgraph/redisgraph
# Events saved for : azure/azure-iot-sdk-c
# Events saved for : astropy/astropy
# Events saved for : littlefs-project/littlefs
# Events saved for : microsoft/msquic
# Events saved for : signalwire/freeswitch
# Events saved for : duet3d/reprapfirmware
# Events saved for : intel/media-driver
# Events saved for : adafruit/adafruit_learning_system_guides
# Events saved for : azure/azure-c-shared-utility
# Events saved for : simbody/simbody
# Events saved for : strukturag/libde265
# Events saved for : tevador/randomx
# Events saved for : xenia-canary/xenia-canary
# Events saved for : natrongithub/natron
# Events saved for : kaskr/adcomp
# Events saved for : khronosgroup/vk-gl-cts
# Events saved for : include-what-you-use/include-what-you-use
# Events saved for : typesense/typesense
# Events saved for : nghttp2/nghttp2
# Events saved for : savoirfairelinux/opendht
# Events saved for : dartsim/dart
# Events saved for : haiwen/seafile-client
# Events saved for : firebase/firebase-cpp-sdk
# Events saved for : fibjs/fibjs
# Events saved for : cockatrice/cockatrice
# Events saved for : eqemu/server
# Events saved for : chia-network/bls-signatures
# Events saved for : kdab/kdsoap
# Events saved for : azuread/microsoft-authentication-library-for-python
# Events saved for : adobe-apiplatform/user-sync.py
# Events saved for : pydicom/pydicom
# Events saved for : pypa/pipenv
# Events saved for : auth0/auth0-python
# Events saved for : mpv-player/mpv
# Events saved for : facebook/zstd
# Events saved for : h2o/h2o
# Events saved for : libvips/libvips
# Events saved for : strongswan/strongswan
# Events saved for : joncampbell123/dosbox-x
# Events saved for : projectacrn/acrn-hypervisor
# Events saved for : spencekonde/attinycore
# Events saved for : openlightingproject/ola
# Events saved for : webassembly/wabt
# Events saved for : neutralinojs/neutralinojs
# Events saved for : trapexit/mergerfs
# Events saved for : unvanquished/unvanquished
# Events saved for : flyinghead/flycast
# Events saved for : phusion/passenger
# Events saved for : hluk/copyq
# Events saved for : oneapi-src/onetbb
# Events saved for : clangen/musikcube
# Events saved for : ultimaker/curaengine
# Events saved for : qtumproject/qtum
# Events saved for : academysoftwarefoundation/opencolorio
# Events saved for : intel/linux-sgx
# Events saved for : namecoin/namecoin-core
# Events saved for : nrel/openstudio
# Events saved for : tencent/hippy
# Events saved for : megengine/megengine
# Events saved for : facebook/mcrouter
# Events saved for : nanocurrency/nano-node
# Events saved for : apache/incubator-pegasus
# Events saved for : dobiasd/frugally-deep
# Events saved for : strukturag/libheif
# Events saved for : inet-framework/inet
# Events saved for : facebookresearch/faiss
# Events saved for : microsoft/winget-cli
# Events saved for : doitsujin/dxvk
# Events saved for : sysown/proxysql
# Events saved for : ledger/ledger
# Events saved for : mosra/magnum
# Events saved for : diasurgical/devilutionx
# Events saved for : stellarium/stellarium
# Events saved for : nem0/lumixengine
# Events saved for : vcmi/vcmi
# Events saved for : flightlessmango/mangohud
# Events saved for : jittor/jittor
# Events saved for : harfbuzz/harfbuzz
# Events saved for : alicevision/alicevision
# Events saved for : stellar-group/hpx
# Events saved for : openxray/xray-16
# Events saved for : leelachesszero/lc0
# Events saved for : opentx/opentx
# Events saved for : owncloud/client
# Events saved for : lightspark/lightspark
# Events saved for : zilliqa/zilliqa
# Events saved for : openboard-org/openboard
# Events saved for : gwaldron/osgearth
# Events saved for : trenchbroom/trenchbroom
# Events saved for : casadi/casadi
# Events saved for : xilinx/vitis-ai
# Events saved for : opensim-org/opensim-core
# Events saved for : p4lang/p4c
# Events saved for : awslabs/amazon-kinesis-video-streams-producer-sdk-cpp
# Events saved for : ibamr/ibamr
# Events saved for : ant-design-blazor/ant-design-blazor
# Events saved for : googleapis/python-pubsub
# Events saved for : allegro/ralph
# Events saved for : yubico/yubikey-manager
# Events saved for : explosion/thinc
# Events saved for : consensys/mythril
# Events saved for : open-io/oio-sds
# Events saved for : ourownstory/neural_prophet
# Events saved for : plaid/plaid-python
# Events saved for : lyft/confidant
# Events saved for : datadog/dd-agent
# Events saved for : huggingface/huggingface_hub
# Events saved for : conda/conda
# Events saved for : ktbyers/netmiko
# Events saved for : pimutils/khal
# Events saved for : pypa/setuptools
# Events saved for : rigetti/pyquil
# Events saved for : datadog/datadogpy
# Events saved for : rasbt/mlxtend
# Events saved for : flexget/flexget
# Events saved for : pyfa-org/pyfa
# Events saved for : nicolargo/glances
# Events saved for : ipython/ipython
# Events saved for : sanic-org/sanic
# Events saved for : fail2ban/fail2ban
# Events saved for : telepresenceio/telepresence
# Events saved for : azavea/raster-vision
# Events saved for : awslabs/sockeye
# Events saved for : netflix/metaflow
# Events saved for : nccgroup/scoutsuite
# Events saved for : jpadilla/pyjwt
# Events saved for : tmux-python/tmuxp
# Events saved for : tomerfiliba/plumbum
# Events saved for : quodlibet/quodlibet
# Events saved for : oracle/oci-cli
# Events saved for : django-cms/django-cms
# Events saved for : archivebox/archivebox
# Events saved for : netbox-community/netbox
# Events saved for : ludwig-ai/ludwig
# Events saved for : kivy/python-for-android
# Events saved for : xonsh/xonsh
# Events saved for : kubernetes-client/python
# Events saved for : python-gitlab/python-gitlab
# Events saved for : onaio/onadata
# Events saved for : aws/deep-learning-containers
# Events saved for : plotly/plotly.py
# Events saved for : simonw/datasette
# Events saved for : cloudtools/troposphere
# Events saved for : twisted/twisted
# Events saved for : mininet/mininet
# Events saved for : ehco1996/django-sspanel
# Events saved for : uber/causalml
# Events saved for : netflix/lemur
# Events saved for : tensorflow/privacy
# Events saved for : owasp/nettacker
# Events saved for : thingsboard/thingsboard-gateway
# Events saved for : aws/aws-parallelcluster
# Events saved for : microsoft/msticpy
# Events saved for : volatilityfoundation/volatility3
# Events saved for : mlcommons/inference
# Events saved for : datadog/datadog-serverless-functions
# Events saved for : googleapis/python-aiplatform
# Events saved for : sparkle-project/sparkle
# Events saved for : couchbase/couchbase-lite-ios
# Events saved for : branchmetrics/react-native-branch-deep-linking-attribution
# Events saved for : coturn/coturn
# Events saved for : redisearch/redisearch
# Events saved for : open62541/open62541
# Events saved for : gpac/gpac
# Events saved for : openssl/openssl
# Events saved for : radareorg/radare2
# Events saved for : timescale/timescaledb
# Events saved for : handbrake/handbrake
# Events saved for : greenplum-db/gpdb
# Events saved for : armmbed/mbed-os
# Events saved for : flatpak/flatpak
# Events saved for : fluent/fluent-bit
# Events saved for : adafruit/circuitpython
# Events saved for : wazuh/wazuh
# Events saved for : frrouting/frr
# Events saved for : rspamd/rspamd
# Events saved for : aflplusplus/aflplusplus
# Events saved for : fwupd/fwupd
# Events saved for : embox/embox
# Events saved for : vesoft-inc/nebula
# Events saved for : atmosphere-nx/atmosphere
# Events saved for : milvus-io/milvus
# Events saved for : zeek/zeek
# Events saved for : beep6581/rawtherapee
# Events saved for : prusa3d/prusa-firmware
# Events saved for : projectchrono/chrono
# Events saved for : osgeo/proj
# Events saved for : opencurve/curve
# Events saved for : eprosima/fast-dds
# Events saved for : mfem/mfem
# Events saved for : ient/yuview
# Events saved for : trilinos/trilinos
# Events saved for : psi4/psi4
# Events saved for : openspace/openspace
# Events saved for : opengisch/qfield
# Events saved for : khronosgroup/vulkan-validationlayers
# Events saved for : dmlc/xgboost
# Events saved for : vowpalwabbit/vowpal_wabbit
# Events saved for : facebook/hermes
# Events saved for : falcosecurity/falco
# Events saved for : nvidia/dali
# Events saved for : prusa3d/prusaslicer
# Events saved for : mozilla/rhino
# Events saved for : osgeo/gdal
# Events saved for : jolibrain/deepdetect
# Events saved for : triton-inference-server/server
# Events saved for : khronosgroup/glslang
# Events saved for : microsoft/directxshadercompiler
# Events saved for : valhalla/valhalla
# Events saved for : facebookresearch/habitat-sim
# Events saved for : tiledb-inc/tiledb
# Events saved for : synfig/synfig
# Events saved for : project-chip/connectedhomeip
# Events saved for : kdab/gammaray
# Events saved for : microsoft/adaptivecards
# Events saved for : realm/realm-core
# Events saved for : borglab/gtsam
# Events saved for : trustwallet/wallet-core
# Events saved for : nrel/energyplus
# Events saved for : fastmachinelearning/hls4ml
# Events saved for : ngageoint/hootenanny
# Events saved for : googleapis/google-cloud-cpp
# Events saved for : electron/electron
# Events saved for : ethereum/solidity
# Events saved for : zerotier/zerotierone
# Events saved for : rr-debugger/rr
# Events saved for : microsoft/onnxruntime
# Events saved for : rapidsai/cudf
# Events saved for : supercollider/supercollider
# Events saved for : arvidn/libtorrent
# Events saved for : esphome/esphome
# Events saved for : oneapi-src/onednn
# Events saved for : oneflow-inc/oneflow
# Events saved for : subsurface/subsurface
# Events saved for : grame-cncm/faust
# Events saved for : introlab/rtabmap
# Events saved for : pytorch/xla
# Events saved for : oracle/graaljs
# Events saved for : cms-sw/cmssw
# Events saved for : oneapi-src/onedal
# Events saved for : azure/azure-sdk-for-cpp
# Events saved for : dotnet/templating
# Events saved for : dotnet/aspnetcore.docs
# Events saved for : dotnet/wpf
# Events saved for : dotnet/winforms
# Events saved for : dotnet/extensions
# Events saved for : datadog/dd-trace-dotnet
# Events saved for : activitywatch/activitywatch
# Events saved for : microsoft/qlib
# Events saved for : pytorch/ignite
# Events saved for : elastic/elasticsearch-py
# Events saved for : napalm-automation/napalm
# Events saved for : projectmesa/mesa
# Events saved for : deepset-ai/haystack
# Events saved for : pypsa/pypsa
# Events saved for : beetbox/beets
# Events saved for : google/clusterfuzz
# Events saved for : googleapis/google-cloud-python
# Events saved for : ctfd/ctfd
# Events saved for : holoviz/holoviews
# Events saved for : tensorflow/model-analysis
# Events saved for : canonical/cloud-init
# Events saved for : rpm-software-management/dnf
# Events saved for : databiosphere/toil
# Events saved for : unit8co/darts
# Events saved for : haiwen/seahub
# Events saved for : googleapis/google-auth-library-python
# Events saved for : scality/zenko
# Events saved for : azure/azure-linux-extensions
# Events saved for : googleapis/python-bigquery
# Events saved for : horovod/horovod
# Events saved for : cython/cython
# Events saved for : hypothesisworks/hypothesis
# Events saved for : optuna/optuna
# Events saved for : celery/kombu
# Events saved for : bridgecrewio/checkov
# Events saved for : modoboa/modoboa
# Events saved for : paddlepaddle/paddleseg
# Events saved for : elastic/detection-rules
# Events saved for : inkstitch/inkstitch
# Events saved for : sfdo-tooling/cumulusci
# Events saved for : googleapis/gapic-generator-python
# Events saved for : numba/numba
# Events saved for : guardicore/monkey
# Events saved for : googleapis/google-api-python-client
# Events saved for : freedomofpress/securedrop
# Events saved for : facebookresearch/nevergrad
# Events saved for : cornellius-gp/gpytorch
# Events saved for : tensorflow/federated
# Events saved for : ceph/ceph-ansible
# Events saved for : ericsson/codechecker
# Events saved for : privacyidea/privacyidea
# Events saved for : tensorflow/model-optimization
# Events saved for : datadog/integrations-core
# Events saved for : datadog/dd-trace-py
# Events saved for : keras-team/keras
# Events saved for : certbot/certbot
# Events saved for : locustio/locust
# Events saved for : aws/serverless-application-model
# Events saved for : alicevision/meshroom
# Events saved for : alteryx/featuretools
# Events saved for : lutris/lutris
# Events saved for : tensorflow/datasets
# Events saved for : pytorch/text
# Events saved for : netflix/dispatch
# Events saved for : fonttools/fonttools
# Events saved for : mitre/caldera
# Events saved for : googlecloudplatform/perfkitbenchmarker
# Events saved for : graphistry/pygraphistry
# Events saved for : tensorflow/addons
# Events saved for : nvaccess/nvda
# Events saved for : esri/arcgis-python-api
# Events saved for : openvinotoolkit/training_extensions
# Events saved for : elastic/ecs
# Events saved for : cfpb/consumerfinance.gov
# Events saved for : scrapy/scrapy
# Events saved for : flairnlp/flair
# Events saved for : frappe/erpnext
# Events saved for : matrix-org/synapse
# Events saved for : prefecthq/prefect
# Events saved for : aws/aws-sam-cli
# Events saved for : django-oscar/django-oscar
# Events saved for : edgedb/edgedb
# Events saved for : microsoft/deepspeed
# Events saved for : dagster-io/dagster
# Events saved for : ultimaker/cura
# Events saved for : microsoft/onefuzz
# Events saved for : vmware/photon
# Events saved for : cobbler/cobbler
# Events saved for : azure/azure-sdk-for-python
# Events saved for : mne-tools/mne-python
# Events saved for : pantsbuild/pants
# Events saved for : pytorch/audio
# Events saved for : blakeblackshear/frigate
# Events saved for : fedml-ai/fedml
# Events saved for : voxel51/fiftyone
# Events saved for : mozilla-mobile/firefox-ios
# Events saved for : kickstarter/ios-oss
# Events saved for : brave/brave-ios
# Events saved for : mapbox/mapbox-navigation-ios
# Events saved for : mapbox/mapbox-directions-swift
# Events saved for : azure/azure-sdk-for-ios
# Events saved for : woocommerce/woocommerce-ios
# Events saved for : material-components/material-components-ios
# Events saved for : aws-amplify/aws-sdk-ios
# Events saved for : vector-im/element-ios
# Events saved for : onesignal/onesignal-ios-sdk
# Events saved for : getsentry/sentry-cocoa
# Events saved for : azuread/microsoft-authentication-library-for-objc
# Events saved for : netdata/netdata
# Events saved for : taosdata/tdengine
# Events saved for : zephyrproject-rtos/zephyr
# Events saved for : riot-os/riot
# Events saved for : upbge/upbge
# Events saved for : tensorflow/tensorflow
# Events saved for : microsoft/powertoys
# Events saved for : protocolbuffers/protobuf
# Events saved for : grpc/grpc
# Events saved for : commaai/openpilot
# Events saved for : facebook/hhvm
# Events saved for : microsoft/react-native-windows
# Events saved for : simdjson/simdjson
# Events saved for : xbmc/xbmc
# Events saved for : google/filament
# Events saved for : apple/foundationdb
# Events saved for : facebook/watchman
# Events saved for : pybind/pybind11
# Events saved for : qgis/qgis
# Events saved for : halide/halide
# Events saved for : openscad/openscad
# Events saved for : clementine-player/clementine
# Events saved for : 4ian/gdevelop
# Events saved for : actor-framework/actor-framework
# Events saved for : openvinotoolkit/openvino
# Events saved for : mavlink/qgroundcontrol
# Events saved for : gothenburgbitfactory/taskwarrior
# Events saved for : cloudcompare/cloudcompare
# Events saved for : icinga/icinga2
# Events saved for : crawl/crawl
# Events saved for : nextcloud/desktop
# Events saved for : multitheftauto/mtasa-blue
# Events saved for : ifcopenshell/ifcopenshell
# Events saved for : hydrogen-music/hydrogen
# Events saved for : abpframework/abp
# Events saved for : orchardcms/orchardcore
# Events saved for : dotnet/roslyn-analyzers
# Events saved for : dotnet/sdk
# Events saved for : huggingface/transformers
# Events saved for : getsentry/sentry
# Events saved for : getredash/redash
# Events saved for : wagtail/wagtail
# Events saved for : googlecloudplatform/microservices-demo
# Events saved for : python-pillow/pillow
# Events saved for : pytest-dev/pytest
# Events saved for : facebookresearch/parlai
# Events saved for : modin-project/modin
# Events saved for : stanfordnlp/stanza
# Events saved for : mindsdb/mindsdb
# Events saved for : federatedai/fate
# Events saved for : quantumlib/cirq
# Events saved for : h2oai/wave
# Events saved for : azure/azure-cli
# Events saved for : galaxyproject/galaxy
# Events saved for : cadquery/cadquery
# Events saved for : learning-at-home/hivemind
# Events saved for : explosion/spacy
# Events saved for : jumpserver/jumpserver
# Events saved for : paddlepaddle/paddle
# Events saved for : streamlit/streamlit
# Events saved for : saltstack/salt
# Events saved for : google/jax
# Events saved for : aio-libs/aiohttp
# Events saved for : rasahq/rasa
# Events saved for : mlflow/mlflow
# Events saved for : pytorch/vision
# Events saved for : openmined/pysyft
# Events saved for : dmlc/dgl
# Events saved for : statsmodels/statsmodels
# Events saved for : scikit-image/scikit-image
# Events saved for : kornia/kornia
# Events saved for : great-expectations/great_expectations
# Events saved for : frappe/frappe
# Events saved for : kubeflow/pipelines
# Events saved for : oppia/oppia
# Events saved for : qiskit/qiskit
# Events saved for : google/flax
# Events saved for : scons/scons
# Events saved for : alpacahq/alpaca-trade-api-python
# Events saved for : simpeg/simpeg
# Events saved for : chia-network/chia-blockchain
# Events saved for : red-hat-storage/ocs-ci
# Events saved for : redis/redis
# Events saved for : darktable-org/darktable
# Events saved for : yugabyte/yugabyte-db
# Events saved for : microsoft/terminal
# Events saved for : facebook/rocksdb
# Events saved for : envoyproxy/envoy
# Events saved for : taichi-dev/taichi
# Events saved for : assimp/assimp
# Events saved for : hrydgard/ppsspp
# Events saved for : musescore/musescore
# Events saved for : pcsx2/pcsx2
# Events saved for : official-stockfish/stockfish
# Events saved for : openttd/openttd
# Events saved for : retroshare/retroshare
# Events saved for : alvr-org/alvr
# Events saved for : kratosmultiphysics/kratos
# Events saved for : applewin/applewin
# Events saved for : kdab/kddockwidgets
# Events saved for : ansible/ansible
# Events saved for : localstack/localstack
# Events saved for : celery/celery
# Events saved for : numpy/numpy
# Events saved for : ansible/awx
# Events saved for : scipy/scipy
# Events saved for : huggingface/datasets
# Events saved for : qutebrowser/qutebrowser
# Events saved for : buildbot/buildbot
# Events saved for : mesonbuild/meson
# Events saved for : internetarchive/openlibrary
# Events saved for : fossasia/open-event-server
# Events saved for : jina-ai/jina
# Events saved for : sabnzbd/sabnzbd
# Events saved for : holoviz/panel
# Events saved for : rospogrigio/localtuya
# Events saved for : firebase/firebase-ios-sdk
# Events saved for : citusdata/citus
# Events saved for : clickhouse/clickhouse
# Events saved for : mamedev/mame
# Events saved for : px4/px4-autopilot
# Events saved for : supertux/supertux
# Events saved for : conan-io/conan
# Events saved for : spack/spack
# Events saved for : paddlepaddle/paddle-lite
# Events saved for : llvm/circt
# Events saved for : dotnet/runtime
# Events saved for : cleverraven/cataclysm-dda
# Events saved for : tensorflow/tfx
# Events saved for : ray-project/ray
# Events saved for : zulip/zulip
# Events saved for : ardupilot/ardupilot
# Events saved for : teradata/covalent
# Events saved for : azure/autorest.typescript
# Events saved for : influxdata/chronograf
# Events saved for : callstack/linaria
# Events saved for : contentful/rich-text
# Events saved for : googleapis/cloud-debug-nodejs
# Events saved for : ionic-team/ionicons
# Events saved for : ionic-team/stencil
# Events saved for : vuejs/vue-class-component
# Events saved for : rsuite/rsuite
# Events saved for : firebase/firebase-admin-node
# Events saved for : esri/arcgis-rest-js
# Events saved for : decentraland/marketplace
# Events saved for : okta/okta-react
# Events saved for : feathersjs/feathers
# Events saved for : angular/angularfire
# Events saved for : electron/fiddle
# Events saved for : microsoft/vscode-react-native
# Events saved for : pixiv/three-vrm
# Events saved for : akveo/nebular
# Events saved for : colinhacks/zod
# Events saved for : litmuschaos/litmus
# Events saved for : googleapis/google-auth-library-nodejs
# Events saved for : c2fo/fast-csv
# Events saved for : getsentry/sentry-react-native
# Events saved for : firebase/extensions
# Events saved for : googleapis/nodejs-bigquery
# Events saved for : walletconnect/walletconnect-monorepo
# Events saved for : googleapis/nodejs-spanner
# Events saved for : codex-team/editor.js
# Events saved for : javascript-obfuscator/javascript-obfuscator
# Events saved for : cucumber/cucumber-js
# Events saved for : actions/cache
# Events saved for : apollographql/apollo-client-devtools
# Events saved for : googleapis/nodejs-pubsub
# Events saved for : contentful/contentful-management.js
# Events saved for : payloadcms/payload
# Events saved for : ianstormtaylor/slate
# Events saved for : verdaccio/verdaccio
# Events saved for : antvis/g6
# Events saved for : callstack/react-native-paper
# Events saved for : ngxs/store
# Events saved for : adaptiveconsulting/reactivetradercloud
# Events saved for : destinyitemmanager/dim
# Events saved for : microsoft/vscode-mssql
# Events saved for : algolia/algoliasearch-client-javascript
# Events saved for : microsoftgraph/microsoft-graph-toolkit
# Events saved for : neo4j/neo4j-browser
# Events saved for : microsoft/applicationinsights-node.js
# Events saved for : elastic/elastic-charts
# Events saved for : contentful/field-editors
# Events saved for : ombi-app/ombi
# Events saved for : pennylaneai/pennylane
# Events saved for : palantir/blueprint
# Events saved for : electron-userland/electron-builder
# Events saved for : typescript-eslint/typescript-eslint
# Events saved for : shoelace-style/shoelace
# Events saved for : react-native-webview/react-native-webview
# Events saved for : alfresco/alfresco-content-app
# Events saved for : nteract/nteract
# Events saved for : microsoft/vscode-cpptools
# Events saved for : microsoft/botbuilder-js
# Events saved for : aws/amazon-chime-sdk-js
# Events saved for : kufu/smarthr-ui
# Events saved for : officedev/microsoft-teams-library-js
# Events saved for : ionic-team/ionic-framework
# Events saved for : vercel/hyper
# Events saved for : alibaba/ice
# Events saved for : apollographql/apollo-client
# Events saved for : material-components/material-components-web
# Events saved for : tensorflow/tfjs
# Events saved for : video-dev/hls.js
# Events saved for : vuestorefront/vue-storefront
# Events saved for : facebook/flipper
# Events saved for : aws-amplify/amplify-js
# Events saved for : prisma/prisma
# Events saved for : vercel/vercel
# Events saved for : getsentry/sentry-javascript
# Events saved for : tensorflow/tensorboard
# Events saved for : angular/universal
# Events saved for : firebase/firebase-tools
# Events saved for : slackapi/node-slack-sdk
# Events saved for : surveyjs/survey-library
# Events saved for : grpc/grpc-node
# Events saved for : microsoft/azure-pipelines-tasks
# Events saved for : sanity-io/sanity
# Events saved for : tagspaces/tagspaces
# Events saved for : aws-amplify/amplify-cli
# Events saved for : coralproject/talk
# Events saved for : microsoft/vscode-pull-request-github
# Events saved for : azuread/microsoft-authentication-library-for-js
# Events saved for : microsoft/vscode-docker
# Events saved for : forcedotcom/salesforcedx-vscode
# Events saved for : opensheetmusicdisplay/opensheetmusicdisplay
# Events saved for : igniteui/igniteui-angular
# Events saved for : alfresco/alfresco-ng2-components
# Events saved for : contentful/forma-36
# Events saved for : provectus/kafka-ui
# Events saved for : smartcontractkit/external-adapters-js
# Events saved for : puppeteer/puppeteer
# Events saved for : storybookjs/storybook
# Events saved for : nestjs/nest
# Events saved for : angular/components
# Events saved for : jquense/yup
# Events saved for : apollographql/apollo-server
# Events saved for : umijs/umi
# Events saved for : foambubble/foam
# Events saved for : ag-grid/ag-grid
# Events saved for : adobe/react-spectrum
# Events saved for : firebase/firebase-js-sdk
# Events saved for : vega/vega-lite
# Events saved for : gitpod-io/gitpod
# Events saved for : hashicorp/terraform-cdk
# Events saved for : wireapp/wire-webapp
# Events saved for : azure/azure-sdk-for-js
# Events saved for : layabox/layaair
# Events saved for : sap/spartacus
# Events saved for : blockchain/blockchain-wallet-v4-frontend
# Events saved for : celo-org/celo-monorepo
# Events saved for : googleapis/repo-automation-bots
# Events saved for : pancakeswap/pancake-frontend
# Events saved for : apache/echarts
# Events saved for : sveltejs/svelte
# Events saved for : vuetifyjs/vuetify
# Events saved for : angular/angular-cli
# Events saved for : mobxjs/mobx
# Events saved for : facebook/docusaurus
# Events saved for : nativescript/nativescript
# Events saved for : eclipse-theia/theia
# Events saved for : webdriverio/webdriverio
# Events saved for : microsoft/azuredatastudio
# Events saved for : jigsaw-code/outline-client
# Events saved for : nrwl/nx
# Events saved for : tinacms/tinacms
# Events saved for : supabase/supabase
# Events saved for : midwayjs/midway
# Events saved for : johannesjo/super-productivity
# Events saved for : microsoft/fluidframework
# Events saved for : appsmithorg/appsmith
# Events saved for : signoz/signoz
# Events saved for : pimoroni/pimoroni-pico
# Events saved for : scikit-learn/scikit-learn
# Events saved for : excalidraw/excalidraw
# Events saved for : pubkey/rxdb
# Events saved for : teambit/bit
# Events saved for : microsoft/fluentui
# Events saved for : pnpm/pnpm
# Events saved for : aws/aws-cdk
# Events saved for : webiny/webiny-js
# Events saved for : ardatan/graphql-tools
# Events saved for : yarnpkg/berry
# Events saved for : webthingsio/gateway
# Events saved for : home-assistant/frontend
# Events saved for : mempool/mempool
# Events saved for : microsoft/typescript
# Events saved for : microsoft/playwright
# Events saved for : chakra-ui/chakra-ui
# Events saved for : blitz-js/blitz
# Events saved for : smogon/pokemon-showdown
# Events saved for : amplication/amplication
# Events saved for : cypress-io/cypress-realworld-app
# Events saved for : dimensiondev/maskbook
# Events saved for : ant-design/ant-design
# Events saved for : n8n-io/n8n
# Events saved for : splunk/security_content
# Events saved for : grafana/grafana
# Events saved for : vitejs/vite
# Events saved for : apple/swift
# Events saved for : trpc/trpc
# Events saved for : renovatebot/renovate
# Events saved for : wolvenkit/wolvenkit
# Events saved for : caffeinemc/sodium-fabric
# Events saved for : airbnb/mavericks
# Events saved for : paddlepaddle/paddlenlp
# Events saved for : amplitude/redux-query
# Events saved for : umap-project/umap
# Events saved for : particle-iot/particle-cli
# Events saved for : antvis/f2
# Events saved for : greenbone/openvas-scanner
# Events saved for : pipedrive/client-nodejs
# Events saved for : artilleryio/artillery
# Events saved for : serialport/node-serialport
# Events saved for : browsersync/browser-sync
# Events saved for : cityofzion/neon-wallet
# Events saved for : responsively-org/responsively-app
# Events saved for : webtorrent/webtorrent-desktop
# Events saved for : vercel/ncc
# Events saved for : ali-sdk/ali-oss
# Events saved for : bpmn-io/diagram-js
# Events saved for : neo4j/neo4j-javascript-driver
# Events saved for : amazon-connect/amazon-connect-streams
# Events saved for : testem/testem
# Events saved for : micheleg/dash-to-dock
# Events saved for : auth0/lock
# Events saved for : alibaba-fusion/next
# Events saved for : supermap/iclient-javascript
# Events saved for : auth0/node-auth0
# Events saved for : seleniumhq/selenium-ide
# Events saved for : inavflight/inav-configurator
# Events saved for : wso2/samples-is
# Events saved for : ueberdosis/tiptap
# Events saved for : balderdashy/sails
# Events saved for : didi/mpx
# Events saved for : nervjs/taro
# Events saved for : ghostery/ghostery-extension
# Events saved for : odoo/owl
# Events saved for : elastic/elasticsearch-js
# Events saved for : nativescript/nativescript-cli
# Events saved for : optimizely/javascript-sdk
# Events saved for : razorpay/blade
# Events saved for : pouchdb/pouchdb
# Events saved for : svaarala/duktape
# Events saved for : elastic/search-ui
# Events saved for : heroku/cli
# Events saved for : microsoft/applicationinsights-js
# Events saved for : ethereum/tests
# Events saved for : asana/node-asana
# Events saved for : mermaid-js/mermaid
# Events saved for : googleapis/google-cloud-node
# Events saved for : efforg/privacybadger
# Events saved for : ohif/viewers
# Events saved for : duckduckgo/duckduckgo-privacy-extension
# Events saved for : alphagov/govuk-frontend
# Events saved for : uber/cadence-web
# Events saved for : pantheon-systems/documentation
# Events saved for : dgtlmoon/changedetection.io
# Events saved for : hubspot/hubspot-cli
# Events saved for : ajaxorg/ace
# Events saved for : marko-js/marko
# Events saved for : okta/okta-signin-widget
# Events saved for : lerna/lerna
# Events saved for : cytoscape/cytoscape.js
# Events saved for : hacker0x01/react-datepicker
# Events saved for : imba/imba
# Events saved for : plone/volto
# Events saved for : shelljs/shelljs
# Events saved for : leeoniya/uplot
# Events saved for : turfjs/turf
# Events saved for : minbrowser/min
# Events saved for : libp2p/js-libp2p
# Events saved for : openlayers/ol-cesium
# Events saved for : nextcloud/calendar
# Events saved for : signalk/signalk-server
# Events saved for : realm/realm-js
# Events saved for : mapbox/mapbox-maps-android
# Events saved for : chinchang/web-maker
# Events saved for : sumup-oss/circuit-ui
# Events saved for : metallb/metallb
# Events saved for : ember-cli/ember-cli
# Events saved for : datadog/dd-trace-js
# Events saved for : poooi/poi
# Events saved for : alphagov/govuk-prototype-kit
# Events saved for : automattic/mongoose
# Events saved for : conventional-changelog/conventional-changelog
# Events saved for : nextauthjs/next-auth
# Events saved for : emberjs/data
# Events saved for : stripe/stripe-node
# Events saved for : itowns/itowns
# Events saved for : frangoteam/fuxa
# Events saved for : contentful/contentful-cli
# Events saved for : knex/knex
# Events saved for : discordjs/discord.js
# Events saved for : wix/detox
# Events saved for : laravel-backpack/crud
# Events saved for : alephdata/aleph
# Events saved for : kiwicom/orbit
# Events saved for : mozilla/addons-frontend
# Events saved for : adobe/aem-project-archetype
# Events saved for : wazuh/wazuh-kibana-app
# Events saved for : rjsf-team/react-jsonschema-form
# Events saved for : pinojs/pino
# Events saved for : cesiumgs/cesium
# Events saved for : facebook/metro
# Events saved for : elementor/elementor
# Events saved for : telerik/kendo-ui-core
# Events saved for : microsoft/botframework-webchat
# Events saved for : adguardteam/adguardbrowserextension
# Events saved for : contentful/contentful.js
# Events saved for : matrix-org/matrix-js-sdk
# Events saved for : kitware/vtk-js
# Events saved for : mozilla/fx-private-relay
# Events saved for : withfig/autocomplete
# Events saved for : cmsgov/design-system
# Events saved for : contentful/contentful-export
# Events saved for : transloadit/uppy
# Events saved for : swagger-api/swagger-ui
# Events saved for : appium/appium
# Events saved for : cartodb/windshaft-cartodb
# Events saved for : leaflet/leaflet
# Events saved for : jitsi/jitsi-meet
# Events saved for : handsontable/handsontable
# Events saved for : mjmlio/mjml
# Events saved for : mifi/lossless-cut
# Events saved for : appbaseio/reactivesearch
# Events saved for : appwrite/appwrite
# Events saved for : tutao/tutanota
# Events saved for : dequelabs/axe-core
# Events saved for : unleash/unleash
# Events saved for : sap/openui5
# Events saved for : budibase/budibase
# Events saved for : mapillary/opensfm
# Events saved for : mattermost/desktop
# Events saved for : netlify/cli
# Events saved for : prebid/prebid.js
# Events saved for : geonode/geonode
# Events saved for : jitsi/lib-jitsi-meet
# Events saved for : sap/ui5-webcomponents
# Events saved for : camunda/camunda-modeler
# Events saved for : medic/cht-core
# Events saved for : sage/carbon
# Events saved for : material-shell/material-shell
# Events saved for : expresslrs/expresslrs
# Events saved for : tryghost/ghost
# Events saved for : strapi/strapi
# Events saved for : cypress-io/cypress
# Events saved for : sequelize/sequelize
# Events saved for : googlechrome/lighthouse
# Events saved for : portainer/portainer
# Events saved for : facebook/relay
# Events saved for : openzeppelin/openzeppelin-contracts
# Events saved for : google/blockly
# Events saved for : invertase/react-native-firebase
# Events saved for : nasa/openmct
# Events saved for : habitrpg/habitica
# Events saved for : mapbox/mapbox-gl-js
# Events saved for : playcanvas/engine
# Events saved for : uber/baseweb
# ...
# Events saved for : gohugoio/hugo
# Events saved for : argoproj/argo-cd
# Events saved for : elastic/elasticsearch-java
# Events saved for : builderio/qwik
# Events saved for : dolthub/dolt
# Events saved for : hashicorp/terraform-provider-aws
# Events saved for : emissary-ingress/emissary
# Events saved for : symfony/symfony
# Events saved for : openfoodfoundation/openfoodnetwork
# Events saved for : kubevirt/kubevirt
# Events saved for : remotion-dev/remotion
# Events saved for : nhost/nhost
# Events saved for : tooljet/tooljet
# Events saved for : yetiforcecompany/yetiforcecrm
# Events saved for : argoproj/argo-workflows
# Events saved for : sourcegraph/sourcegraph
# Events saved for : smartcontractkit/chainlink
# Events saved for : filecoin-project/lotus
# Events saved for : ethereum-optimism/optimism
# Events saved for : spree/spree
# Events saved for : rubyforgood/human-essentials
# Events saved for : ethereum/go-ethereum
# Events saved for : cilium/cilium
# Events saved for : dataease/dataease
# Events saved for : backstage/backstage
# Events saved for : aidenybai/million
# Events saved for : zebrunner/carina
# Events saved for : nextcloud/server
# Events saved for : statelyai/xstate
# Events saved for : cloudwego/kitex
# Events saved for : ledgerwatch/erigon
# Events saved for : socioboard/socioboard-5.0
# Events saved for : eugeny/tabby
# Events saved for : mastodon/mastodon
# Events saved for : grafana/k6
# Events saved for : kubernetes/kops
# Events saved for : communitytoolkit/maui
# Events saved for : apache/pinot
# Events saved for : louislam/uptime-kuma
# Events saved for : expensify/app
# Events saved for : streetwriters/notesnook
# Events saved for : isl-org/open3d
# Events saved for : shopify/polaris
# Events saved for : onionshare/onionshare
# Events saved for : material-components/material-web
# Events saved for : ethereum/consensus-specs
# Events saved for : wpengine/faustjs
# Events saved for : aws-amplify/amplify-ui
# Events saved for : hashicorp/terraform-provider-azurerm
# Events saved for : flipperdevices/flipperzero-firmware
# Events saved for : unity-technologies/com.unity.netcode.gameobjects
# Events saved for : bdring/fluidnc
# Events saved for : owncloud/web
# Events saved for : keplergl/kepler.gl
# Events saved for : huggingface/optimum
# Events saved for : asynkron/protoactor-dotnet
# Events saved for : wiremock/wiremock
# Events saved for : mandiant/capa
# Events saved for : llvm/torch-mlir
# Events saved for : pyg-team/pytorch_geometric
# Events saved for : rails/rails
# Events saved for : cloudfoundry/garden-runc-release
# Events saved for : ceph/ceph-container
# Events saved for : crosstool-ng/crosstool-ng
# Events saved for : openflagr/flagr
# Events saved for : saleor/saleor
# Events saved for : awesomemotive/easy-digital-downloads
# Events saved for : longhorn/longhorn
# Events saved for : hestiacp/hestiacp
# Events saved for : winetricks/winetricks
# Events saved for : sameersbn/docker-gitlab
# Events saved for : scop/bash-completion
# Events saved for : kata-containers/tests
# Events saved for : questpdf/questpdf
# Events saved for : yaklang/yakit
# Events saved for : jupyterlab/jupyterlab-desktop
# Events saved for : openconfig/public
# Events saved for : gameservermanagers/linuxgsm
# Events saved for : multimc/launcher
# Events saved for : rasterio/rasterio
# Events saved for : hpcaitech/colossalai
# Events saved for : uniswap/interface
# Events saved for : tasemulators/bizhawk
# Events saved for : armbian/build
# Events saved for : vercel/examples
# Events saved for : deepfence/threatmapper
# Events saved for : ballerina-platform/ballerina-distribution
# Events saved for : communitytoolkit/dotnet
# Events saved for : dbt-labs/dbt-core
# Events saved for : shopify/hydrogen
# Events saved for : stan-dev/stan
# Events saved for : facebookresearch/xformers
# Events saved for : redisjson/redisjson
# Events saved for : douyinfe/semi-design
# Events saved for : wordpress/performance
# Events saved for : mydumper/mydumper
# Events saved for : ultraleap/unityplugin
# Events saved for : ethereum/remix-project
# Events saved for : jaredpalmer/formik
# Events saved for : gitkraken/vscode-gitlens
# Events saved for : officedev/office-add-in-samples
# Events saved for : apollographql/apollo-kotlin
# Events saved for : mattermost/focalboard
# Events saved for : beyonddimension/steamtools
# Events saved for : coder/code-server
# Events saved for : fish-shell/fish-shell
# Events saved for : shopify/react-native-skia
# Events saved for : projectcalico/calico
# Events saved for : onekeyhq/app-monorepo
# Events saved for : pingcap/tiflow
# Events saved for : openedx/edx-app-android
# Events saved for : openedx/edx-ora2
# Events saved for : openedx/devstack
# Events saved for : kedro-org/kedro
# Events saved for : textualize/textual
# Events saved for : openedx/xblock
# Events saved for : cubefs/cubefs
# Events saved for : googleforcreators/web-stories-wp
# Events saved for : jelmer/dulwich
# Events saved for : nextflow-io/nextflow
# Events saved for : palantir/gradle-docker
# Events saved for : supabase/realtime
# Events saved for : getsentry/sentry-dart
# Events saved for : webrtc-rs/webrtc
# Events saved for : rust-bio/rust-bio
# Events saved for : getsentry/sentry-cli
# Events saved for : libxsmm/libxsmm
# Events saved for : dart-lang/linter
# Events saved for : tikv/raft-rs
# Events saved for : paritytech/wasmi
# Events saved for : spring-projects/spring-data-relational
# Events saved for : zino-hofmann/graphql-flutter
# Events saved for : neovide/neovide
# Events saved for : rust-lang/rustlings
# Events saved for : rustls/rustls
# Events saved for : filecoin-project/rust-fil-proofs
# Events saved for : plausible/analytics
# Events saved for : getsentry/sentry-rust
# Events saved for : rundeck/rundeck
# Events saved for : jonataslaw/getx
# Events saved for : flutter/devtools
# Events saved for : aws-amplify/amplify-flutter
# Events saved for : tree-sitter/tree-sitter
# Events saved for : quinn-rs/quinn
# Events saved for : meilisearch/meilisearch
# Events saved for : lemmynet/lemmy
# Events saved for : starcoinorg/starcoin
# Events saved for : helium/gateway-rs
# Events saved for : fuellabs/fuel-core
# Events saved for : appflowy-io/appflowy
# Events saved for : actix/actix-web
# Events saved for : bytecodealliance/wasmtime
# Events saved for : lapce/lapce
# Events saved for : huggingface/tokenizers
# Events saved for : gfx-rs/wgpu
# Events saved for : sigp/lighthouse
# Events saved for : aleohq/snarkos
# Events saved for : nervosnetwork/ckb
# Events saved for : holochain/holochain
# Events saved for : fuellabs/sway
# Events saved for : shaka-project/shaka-player
# Events saved for : wasmerio/wasmer
# Events saved for : habitat-sh/habitat
# Events saved for : alacritty/alacritty
# Events saved for : firecracker-microvm/firecracker
# Events saved for : tokio-rs/tokio
# Events saved for : a-b-street/abstreet
# Events saved for : quickwit-oss/tantivy
# Events saved for : cloudflare/quiche
# Events saved for : tock/tock
# Events saved for : dioxuslabs/dioxus
# Events saved for : rust-windowing/winit
# Events saved for : libp2p/rust-libp2p
# Events saved for : mullvad/mullvadvpn-app
# Events saved for : wilfred/difftastic
# Events saved for : mobilecoinfoundation/mobilecoin
# Events saved for : paritytech/ink
# Events saved for : acalanetwork/acala
# Events saved for : getsentry/relay
# Events saved for : oracle/terraform-provider-oci
# Events saved for : gradle/gradle
# Events saved for : blockscout/blockscout
# Events saved for : datahub-project/datahub
# Events saved for : firebase/flutterfire
# Events saved for : qdrant/qdrant
# Events saved for : netbirdio/netbird
# Events saved for : canonical/microk8s
# Events saved for : bnb-chain/bsc
# Events saved for : 0xpolygon/polygon-edge
# Events saved for : tikv/tikv
# Events saved for : pingcap/tiflash
# Events saved for : solana-labs/solana-program-library
# Events saved for : scverse/scanpy
# Events saved for : openbb-finance/openbbterminal
# Events saved for : xianyi/openblas
# Events saved for : microsoft/winui-gallery
# Events saved for : nomicfoundation/hardhat
# Events saved for : cert-manager/cert-manager
# Events saved for : tauri-apps/tauri
# Events saved for : diesel-rs/diesel
# Events saved for : graphprotocol/graph-node
# Events saved for : mbed-tls/mbedtls
# Events saved for : vuejs/core
# Events saved for : apache/incubator-hugegraph
# Events saved for : novuhq/novu
# Events saved for : ecomfe/veui
# Events saved for : slint-ui/slint
# Events saved for : nodesolidserver/node-solid-server
# Events saved for : nutsdb/nutsdb
# Events saved for : sushiswap/sushiswap
# Events saved for : siderolabs/talos
# Events saved for : elastic/elastic-agent
# Events saved for : shopify/ruby-lsp
# Events saved for : openedx/paragon
# Events saved for : ccfos/nightingale
# Events saved for : facebookresearch/fairseq
# Events saved for : emilk/egui
# Events saved for : usememos/memos
# Events saved for : wazuh/wazuh-docker
# Events saved for : snyk/cli
# Events saved for : bitwarden/clients
# Events saved for : concretecms/concretecms
# Events saved for : py-why/dowhy
# Events saved for : sei-protocol/sei-chain
# Events saved for : woocommerce/woocommerce-blocks
# Events saved for : quickwit-oss/quickwit
# Events saved for : thundernest/k-9
# Events saved for : apache/age
# Events saved for : apache/inlong
# Events saved for : dragonflydb/dragonfly
# Events saved for : lightning-ai/lightning
# Events saved for : grafana/oncall
# Events saved for : denoland/fresh
# Events saved for : shopify/shopify-api-ruby
# Events saved for : huggingface/diffusers
# Events saved for : ipfs/kubo
# Events saved for : hummerrisk/hummerrisk
# Events saved for : nvidia/nemo
# Events saved for : zdoom/gzdoom
# Events saved for : vectordotdev/vector
# Events saved for : enso-org/enso
# Events saved for : materializeinc/materialize
# Events saved for : near/nearcore
# Events saved for : bigscience-workshop/petals
# Events saved for : melonds-emu/melonds
# Events saved for : pydantic/pydantic
# Events saved for : immich-app/immich
# Events saved for : denoland/deno
# Events saved for : foundry-rs/foundry
# Events saved for : risingwavelabs/risingwave
# Events saved for : wormhole-foundation/wormhole
# Events saved for : eclipse-californium/californium
# Events saved for : viewcomponent/view_component
# Events saved for : hyprwm/hyprland
# Events saved for : skypilot-org/skypilot
# Events saved for : seaweedfs/seaweedfs
# Events saved for : kubescape/kubescape
# Events saved for : ggerganov/whisper.cpp
# Events saved for : apache/doris
# Events saved for : containers/podman
# Events saved for : livekit/livekit
# Events saved for : azure/azure-dev
# Events saved for : sagernet/sing-box
# Events saved for : vitessio/vitess
# Events saved for : huggingface/text-generation-inference
# Events saved for : aws-amplify/amplify-swift
# Events saved for : grafana/mimir
# Events saved for : goss-org/goss
# Events saved for : evmos/evmos
# Events saved for : yubico/yubioath-flutter
# Events saved for : build-trust/ockam
# Events saved for : saml-toolkits/php-saml
# Events saved for : solana-labs/solana
# Events saved for : kubeshark/kubeshark
# Events saved for : ng-alain/ng-alain
# Events saved for : modelscope/modelscope
# Events saved for : mystenlabs/sui
# Events saved for : neondatabase/neon
# Events saved for : urbanairship/react-native-airship
# Events saved for : mirrornetworking/mirror
# Events saved for : bloopai/bloop
# Events saved for : quic-go/quic-go
# Events saved for : electron/forge
# Events saved for : leptos-rs/leptos
# Events saved for : redis/go-redis
# Events saved for : weaviate/weaviate
# Events saved for : opendds/opendds
# Events saved for : hyperledger-labs/blockchain-explorer
# Events saved for : decaporg/decap-cms
# Events saved for : abdullahalfaraj/auto-photoshop-stablediffusion-plugin
# Events saved for : shopify/hydrogen-v1
# Events saved for : grapesjs/grapesjs
# Events saved for : grafana/pyroscope
# Events saved for : standardrb/standard
# Events saved for : googleapis/release-please
# Events saved for : metamask/core
# Events saved for : hoppscotch/hoppscotch
# Events saved for : ydataai/ydata-profiling
# Events saved for : super-linter/super-linter
# Events saved for : kubevela/kubevela
# Events saved for : frappe/books
# Events saved for : opencv/cvat
# Events saved for : apitable/apitable
# Events saved for : algolia/instantsearch
# Events saved for : tahowallet/extension
# Events saved for : shopify/cli
# Events saved for : scratchfoundation/scratch-vm
# Events saved for : jetbrains/compose-multiplatform
# Events saved for : tencentblueking/bk-sops
# Events saved for : huggingface/pytorch-image-models
# Events saved for : shopify/shopify-api-js
# Events saved for : langgenius/dify
# Events saved for : jqlang/jq
# Events saved for : chillicream/graphql-platform
# Events saved for : kubeflow/kubeflow
# Events saved for : ordinals/ord
# Events saved for : bytecodealliance/javy
# Events saved for : flexn-io/renative
# Events saved for : scratchfoundation/scratch-gui
# Events saved for : tidev/titanium-sdk
# Events saved for : apache/eventmesh
# Events saved for : jolokia/jolokia
# Events saved for : eclipse-leshan/leshan
# Events saved for : nocodb/nocodb
# Events saved for : microsoftgraph/msgraph-sdk-powershell
# Events saved for : autogluon/autogluon
# Events saved for : radeonopencompute/rocm
# Events saved for : datopian/portaljs
# Events saved for : vector-im/element-web
# Events saved for : consuldemocracy/consuldemocracy
# Events saved for : livewire/livewire
# Events saved for : bmaltais/kohya_ss
# Events saved for : electricitymaps/electricitymaps-contrib
# Events saved for : eosphoros-ai/DB-GPT
# Events saved for : mikel-brostrom/yolo_tracking
# Events saved for : jerryjliu/llama_index
# Events saved for : HumanSignal/label-studio
# Events saved for : chroma-core/chroma
# Events saved for : mage-ai/mage-ai
# Events saved for : TransformerOptimus/SuperAGI
# Events saved for : wandb/wandb
# Events saved for : activeloopai/deeplake
# Events saved for : logspace-ai/langflow
# Events saved for : reflex-dev/reflex
# Events saved for : sktime/sktime
# Events saved for : nerfstudio-project/nerfstudio
# Events saved for : StarRocks/starrocks
# Events saved for : portfolio-performance/portfolio
# Events saved for : eksctl-io/eksctl
# Events saved for : ServiceWeaver/weaver
# Events saved for : sqlc-dev/sqlc
# Events saved for : istio/istio
# Events saved for : coder/coder
# Events saved for : web3/web3.js
# Events saved for : ariakit/ariakit
# Events saved for : iTwin/itwinjs-core
# Events saved for : reworkd/AgentGPT
# Events saved for : sst/sst
# Events saved for : openai-translator/openai-translator
# Events saved for : dotnet/vscode-csharp
# Events saved for : MetaMask/snaps
# Events saved for : hasura/graphql-engine
# Events saved for : makeplane/plane
# Events saved for : mui/material-ui
# Events saved for : nuxt/nuxt
# Events saved for : withastro/astro
# Events saved for : calcom/cal.com
# Events saved for : lensterxyz/lenster
# Events saved for : element-plus/element-plus
# Events saved for : StanGirard/quivr
# Events saved for : FlowiseAI/Flowise
# Events saved for : winglang/wing
# Events saved for : Shaunwei/RealChar
# Events saved for : termux/termux-packages
# Events saved for : facebook/lexical
# Events saved for : flybywiresim/aircraft
# Events saved for : ggerganov/llama.cpp
# Events saved for : jmorganca/ollama
# Events saved for : bevyengine/bevy
# Events saved for : vercel/turbo
# Events saved for : pola-rs/polars
# Events saved for : cube-js/cube
# Events saved for : aptos-labs/aptos-core
# Events saved for : openxla/iree
# Events saved for : chaitin/HummerRisk
# Events saved for : pymupdf/PyMuPDF
# Events saved for : langchain-ai/langchain
# Events saved for : apache/airflow
# Events saved for : huggingface/trl
# Events saved for : astral-sh/ruff
# Events saved for : cloudflare/workerd
# Events saved for : taiga-family/taiga-ui
# Events saved for : mattermost/mattermost
# Events saved for : Esri/calcite-design-system
# Events saved for : toeverything/AFFiNE
# Events saved for : hwchase17/langchainjs
# Events saved for : kubernetes/kubernetes
# Events saved for : microsoft/semantic-kernel
# Events saved for : home-assistant/core
# Events saved for : bytebase/bytebase
# Events saved for : nodejs/node
# Events saved for : hackforla/website
# Events saved for : fonttools/fontbakery
# Events saved for : invoke-ai/InvokeAI
# Events saved for : amazon-braket/amazon-braket-sdk-python
# Events saved for : langchain-ai/langchainjs
# Events saved for : google-deepmind/open_spiel
